# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('weight_height.csv')
print(dataset.head(5))
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
x =dataset.iloc[:, :-1].values
x
# Out:
# array([[73.84701702],
#        [68.78190405],
#        [74.11010539],
#        ...,
#        [63.86799221],
#        [69.03424313],
#        [61.94424588]])

# %%
y = dataset.iloc[:,-1].values
y
# Out:
# array([241.8935632, 162.3104725, 212.7408556, ..., 128.4753188,
#        163.8524613, 113.6491027])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state =0)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
x_val = np.arange(min(x_train), max(x_train), 0.01)
x_val = x_val.reshape((len(x_val),1))
plt.scatter(x_train, y_train, color = 'green')
plt.plot(x_val, model.predict(x_val), color = 'red')
plt.title('Wight predicton using DecisonTree')
plt.xlabel('Hight')
plt.ylabel('wight')
plt.figure()
plt.show()

# %%
y_pred = model.predict(x_test)

from sklearn.metrics import r2_score, mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("root mean squre error:",rmse)
r2score = r2_score(y_test, y_pred)
print("R2Score",r2score*100)
# Out:
# root mean squre error: 16.723526606012587
# R2Score 72.93550733446492
